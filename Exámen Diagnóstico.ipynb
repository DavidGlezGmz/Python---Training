# %% [markdown]
# ## EXAMEN DIAGNOSTICO

# %% [markdown]
# # Ejercicio 1
#
# Dado un año, devuelva el siglo en el que se encuentra.
#
# El primer siglo abarca del año 1 al año 100
#
# El segundo siglo abarca del año 101 al año 200
#
# Asi sucesivamente...

# %%
def solucion(año):
  
  return año//101 + 1

# %%
print ("Año: 1750, Siglo:", solucion(1720), "\t  Siglo esperado: 18")
print ("Año: 850, Siglo:", solucion(850), "\t  Siglo esperado: 9")
print ("Año: 2022, Siglo:", solucion(2022), "\t  Siglo esperado: 21")
# Out:
# Año: 1750, Siglo: 18 	  Siglo esperado: 18
# Año: 850, Siglo: 9 	  Siglo esperado: 9
# Año: 2022, Siglo: 21 	  Siglo esperado: 21

# %% [markdown]
# # Ejercicio 2
#
# Dada una matriz de enteros, encuentra el par de elementos adyacentes que tiene el producto más grande y devuelve ese producto.

# %%
def solucion(A):

  return

# %%
print ("[-23, 4, -3, 8, -12], Mayor producto par:", solucion([-23, 4, -3, 8, -12]), "\t Salida deseada: -12")
print ("[3, 6, -2, -5, 7, 3], Mayor producto par:", solucion([3, 6, -2, -5, 7, 3]), "\t Salida deseada: 21")
print ("[1, 0, 1, 0, 1000], Mayor producto par:", solucion([1, 0, 1, 0, 1000]), "\t Salida deseada: 0")
# Out:
# [-23, 4, -3, 8, -12], Mayor producto par: -12 	 Salida deseada: -12
# [3, 6, -2, -5, 7, 3], Mayor producto par: 21 	 Salida deseada: 21
# [1, 0, 1, 0, 1000], Mayor producto par: 0 	 Salida deseada: 0
